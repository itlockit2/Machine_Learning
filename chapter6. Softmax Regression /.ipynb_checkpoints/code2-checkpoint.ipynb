# %%
import tensorflow as tf
import numpy as np

# %%
xy = np.loadtxt('data-04-zoo.csv', delimiter=',', dtype=np.float32)
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

X = tf.placeholder(tf.float32, [None,16])
Y = tf.placeholder(tf.int32, [None,1])
nb_classes = 7

Y_one_hot = tf.one_hot(Y,nb_classes)
Y_one_hot = tf.reshape(Y_one_hot, [-1,nb_classes])

W = tf.Variable(tf.random_normal([16,nb_classes]), name='weight')
b = tf.Variable(tf.random_normal([nb_classes]), name='bias')

# %%
# tf.nn.softmax computes softmax activations
# softmax = exp(logits) / reduce_sum(exp(Logits), dim)
logits = tf.matmul(X,W) + b
hypothesis = tf.nn.softmax(logits)

# Cross entropy cost/loss
cost_i = tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels=Y_one_hot)
cost = tf.reduce_mean(cost_i)
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

prediction = tf.argmax(hypothesis,1) 
correct_prediction = tf.equal(prediction, tf.argmax(Y_one_hot, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# Launch graph
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(2001):
        sess.run(optimizer, feed_dict={X:x_data, Y:y_data})
        if step % 200 == 0:
            loss, acc = sess.run([cost,accuracy], feed_dict={X:x_data, Y:y_data})
            print("step = ", step , "Loss = ", loss, "Acc = ", acc)
    # Let's see if we can predict
    pred = sess.run(prediction, feed_dict={X : x_data})

    for p, y in zip(pred, y_data.flatten()):
        print("Prediction = " , p , "True Y = " , y)
# Out:
# step =  0 Loss =  3.9428978 Acc =  0.16831683
# step =  200 Loss =  0.45955098 Acc =  0.8811881
# step =  400 Loss =  0.27585784 Acc =  0.9306931
# step =  600 Loss =  0.19286868 Acc =  0.97029704
# step =  800 Loss =  0.144145 Acc =  0.97029704
# step =  1000 Loss =  0.11343229 Acc =  0.990099
# step =  1200 Loss =  0.093199134 Acc =  1.0
# step =  1400 Loss =  0.079154745 Acc =  1.0
# step =  1600 Loss =  0.06889439 Acc =  1.0
# step =  1800 Loss =  0.061072696 Acc =  1.0
# step =  2000 Loss =  0.05490605 Acc =  1.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  3 True Y =  3.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  3 True Y =  3.0
# Prediction =  3 True Y =  3.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  3 True Y =  3.0
# Prediction =  6 True Y =  6.0
# Prediction =  6 True Y =  6.0
# Prediction =  6 True Y =  6.0
# Prediction =  1 True Y =  1.0
# Prediction =  0 True Y =  0.0
# Prediction =  3 True Y =  3.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  1 True Y =  1.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  5 True Y =  5.0
# Prediction =  4 True Y =  4.0
# Prediction =  4 True Y =  4.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  5 True Y =  5.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  3 True Y =  3.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  3 True Y =  3.0
# Prediction =  5 True Y =  5.0
# Prediction =  5 True Y =  5.0
# Prediction =  1 True Y =  1.0
# Prediction =  5 True Y =  5.0
# Prediction =  1 True Y =  1.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  6 True Y =  6.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  5 True Y =  5.0
# Prediction =  4 True Y =  4.0
# Prediction =  6 True Y =  6.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  1 True Y =  1.0
# Prediction =  1 True Y =  1.0
# Prediction =  1 True Y =  1.0
# Prediction =  3 True Y =  3.0
# Prediction =  3 True Y =  3.0
# Prediction =  2 True Y =  2.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  6 True Y =  6.0
# Prediction =  3 True Y =  3.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  2 True Y =  2.0
# Prediction =  6 True Y =  6.0
# Prediction =  1 True Y =  1.0
# Prediction =  1 True Y =  1.0
# Prediction =  2 True Y =  2.0
# Prediction =  6 True Y =  6.0
# Prediction =  3 True Y =  3.0
# Prediction =  1 True Y =  1.0
# Prediction =  0 True Y =  0.0
# Prediction =  6 True Y =  6.0
# Prediction =  3 True Y =  3.0
# Prediction =  1 True Y =  1.0
# Prediction =  5 True Y =  5.0
# Prediction =  4 True Y =  4.0
# Prediction =  2 True Y =  2.0
# Prediction =  2 True Y =  2.0
# Prediction =  3 True Y =  3.0
# Prediction =  0 True Y =  0.0
# Prediction =  0 True Y =  0.0
# Prediction =  1 True Y =  1.0
# Prediction =  0 True Y =  0.0
# Prediction =  5 True Y =  5.0
# Prediction =  0 True Y =  0.0
# Prediction =  6 True Y =  6.0
# Prediction =  1 True Y =  1.0
